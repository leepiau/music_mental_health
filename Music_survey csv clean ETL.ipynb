# %% [markdown]
# # Music and Mental Health

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***Content:***
# 1. Background Information
#
# 2. Data Sets
#     2.1 Data Sets Used
#     2.2 Variables and Definitions
#     2.3 Importing Libraries
#     2.4 General overview
#
#
# 3. Data Cleaning and Transformation
#     3.1 Data Cleaning
#
# 4. Create database in postgreSQL
#
# 5. Create table in PostgreSQL
#
# 6. Read from PostgreSQL

# %% [markdown]
# #### 1. Background Information

# %% [markdown]
# Music Therapy is using music interventions to help individuals accomplish their goals with a certified music therapist. Music therapy can assist in promoting wellness, managing stress, expressing feelings, enhancing memory, improving communication and more.
# Music therapy, or MT, is the use of music to improve an individual's stress, mood, and overall mental health. MT is also recognized as an evidence-based practice, using music as a catalyst for "happy" hormones such as oxytocin.
#
# The music preference of individuals of different ages, and the effect this choice of music has on their mental health.

# %% [markdown]
# #### 2. Data Sets

# %% [markdown]
# ***2.1 Data Sets Used***
#
# In this project, We will use the Kaggle Dataset that contains data relating to a research about Music Therapy.
# Music & Mental Health Survey Results
#
# About the data:
#
# Reliable- Subjective to accuracy of self-report
#
# Original- Data is from survey participants
#
# Comprehensive- Lots of variables related to music listener habits. Unable to determine causation of effect music had on listeners with data provided

# %% [markdown]
# **2.2 Variables  and 	Definitions**
#
# For a better comprehension of the variables on the dataset, I will create a table with the definitions for each one:
#
#
# Timestamp -	Date and Time when the survey was completed by the participant.
#
# Age- Participant's age.
#
# Primary Streaming Service -	What is the main streaming service that the participant uses.
#
# Hours per Day -Number of hours the participant listens to music per day.
#
# While Working -	Does the participant listen to music while working?
#
# Instrumentalist - Does the participant play a musical instrument regularly?
#
# Composer - Does the participant compose music?
#
# Fav Genre - Participant's favorite/most listened to music genre.
#
# Exploratory - Does the participant actively seek out different genres of music?
#
# Foreign Languages -	Does the participant regularly listen to music in foreign languages?
#
# BPM - Beats per Minute of the participant's favorite music genre.
#
# Frequency [Classical] - How often does the participant listen to Classical music.
#
# Frequency [Country]	- How often does the participant listen to Country music.
#
# Frequency [EDM] - How often does the participant listen to EDM music.
#
# Frequency [Folk] - How often does the participant listen to folk music.
#
# Frequency [Gospel] - How often does the participant listen to Gospel music.
#
# Frequency [Hip Hop] - How often does the participant listen to Hip Hop.
#
# Frequency [Jazz]- How often does the participant listen to Jazz.
#
# Frequency [K Pop] - How often does the participant listen to K Pop.
#
# Frequency [Latin] - How often does the participant listen to Latin music.
#
# Frequency [Lofi] - How often does the participant listen to Lofi.
#
# Frequency [Metal] - How often does the participant listen to Metal.
#
# Frequency [Pop] - How often does the participant listen to pop music.
#
# Frequency [R&B]	- How often does the participant listen to R&B (Rhythm and Blues).
#
# Frequency [Rap]	- How often does the participant listen to Rap.
#
# Frequency [Rock] -How often does the participant listen to Rock.
#
# Frequency [Video Game Music] - How often does the participant listen to Video Game Music.
#
# Anxiety - Anxiety level (rated from 0-10) reported by the participant.
#
# Drepession - Level of depression (rated 0-10) reported by participant.
#
# Insomnia - Level of insomnia (rated 0-10) reported by participant.
#
# OCD - OCD Level (rated from 0-10) reported by participant.
#
# Music Effects -	Music improve or worsen the participant's mental health?
#
# Permissions	- Permissions granted by participants to publish data.

# %% [markdown]
#  #### 3.1 Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import sqlalchemy as db

# %%
# create a dataframe from csv file
#df = pd.read_csv('https://raw.githubusercontent.com/leepiau/music_mental_health/main/mxmh_survey_results.csv')
df = pd.read_csv("C:\\Users\\Abhirami\\Desktop\\Internal_Project\\Project\\mxmh_survey_results.csv")

# %% [markdown]
# #### 2.3 General overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %% [markdown]
# Out of 33 columns 26 columns are Object type and rest are Numeric type.
# The dataset contains 736 entries in 33 different variables
#
# Some remarks about the data:
#
# Some columns have null values;
#
# The BPM column contains the most null values;
#
# The Timestamp column have no purpose for this analysis;
#
# The Permissions column is not necessary for our analysis. This is because the values in this column are as follows: "I understand."

# %% [markdown]
# #### 3. Data Cleaning and Transformation

# %%
# !pip install sqlalchemy
# !pip install psycopg2

# %%
# !pip install sqlalchemy_utils

# %% [markdown]
# #### 3.1 Data Cleaning

# %%
# from sqlalchemy_utils import create_database

# # user postgres, password, admin
# # for example, one wants to create a new db, say, starter
# engine = db.create_engine('postgresql://postgres:admin@localhost:5434/musicdb')

# # create database
# create_database(engine.url)

# # release resources associated with engine
# engine.dispose()

# %%
# Using the .describe() method on the categorical columns:
#data.describe(exclude='number').T

# %% [markdown]
# After getting to know the characteristics of our Dataset better and understanding the situations of outlier values, we will move on to the data cleaning and transformation stage, where we will leave the data in the best possible form for later graphic visualizations.
#
# As steps we will have:
#
# Check the duplicate columns
#
# Dropcolumns:
# The Timestamp column have no purpose for this analysis;
#
# The Permissions column is not necessary for our analysis. This is because the values in this column are as follows: "I understand."
#
# Clean column names:
# strip leading/trailing whitespaces, convert to lowercase, replace spaces with underscores
#
# Insert new columns:
# "id" -increase its value by 1
# "freq1","freq2", "freq3" - populate with the genres consumed 'Very frequently
# "age_group" - column and their corresponding ranges
#
# Remove in data value 'frequency_' from genres in 'freq1',' freq2', 'freq3'

# %%
# Check the duplicate columns
df=df.drop_duplicates()

# %%
# Drop 'Timestamp' and 'Permissions' columns 
df.drop(columns=['Timestamp', 'Permissions'], inplace=True)

# %%
# Clean column names: strip leading/trailing whitespaces, convert to lowercase, replace spaces with underscores
keys = list(df.columns)

formatted_keys = {key: key.lower().replace(' ', '_').replace('[', '').replace(']', '').replace('&', '_n_') for key in keys}

df = df.rename(columns = formatted_keys)

# %%
# Insert new column 'id' and increase its value by 1
df.insert(0, 'id', range(1, 1 + len(df)))
#print(df)
# Out:
#       id   age primary_streaming_service  hours_per_day while_working  \
# 0      1  18.0                   Spotify            3.0           Yes
# 1      2  63.0                   Pandora            1.5           Yes
# 2      3  18.0                   Spotify            4.0            No
# 3      4  61.0             YouTube Music            2.5           Yes
# 4      5  18.0                   Spotify            4.0           Yes
# ..   ...   ...                       ...            ...           ...
# 731  732  17.0                   Spotify            2.0           Yes
# 732  733  18.0                   Spotify            1.0           Yes
# 733  734  19.0   Other streaming service            6.0           Yes
# 734  735  19.0                   Spotify            5.0           Yes
# 735  736  29.0             YouTube Music            2.0           Yes
#
#     instrumentalist composer         fav_genre exploratory foreign_languages  \
# ...

# %%
# Decide to create 3 new cols per row and populate with the genres consumed 'Very frequently'
def find_frequencies(row):
    frequencies = [col for col in df.columns if row[col] == 'Very frequently']
    return pd.Series(frequencies + [None]*3)[:3]

# Apply the function to the DataFrame
df[['freq1', 'freq2', 'freq3']] = df.apply(find_frequencies, axis=1)

# %%
#Remove frequency_ from genres in 'freq1',' freq2', 'freq3'
for i in range(1,4):
    df[f'freq{i}'] = df[f'freq{i}'].str.replace('frequency_', '').str.replace('_', '-')

# %%
# Create 'age_group' column and their corresponding ranges 
age_group = pd.cut(df['age'],
                         bins=[0, 18, 35, 60, 75, 100],
                         labels=['early_years', 'young_adults', 'middle_age', 'mature_adults', 'elderly'], right = False)
df.insert(1, 'age_group', age_group)

# %%
#Display the DataFrame
print(df)
# Out:
#       id      age_group   age primary_streaming_service  hours_per_day  \
# 0      1   young_adults  18.0                   Spotify            3.0
# 1      2  mature_adults  63.0                   Pandora            1.5
# 2      3   young_adults  18.0                   Spotify            4.0
# 3      4  mature_adults  61.0             YouTube Music            2.5
# 4      5   young_adults  18.0                   Spotify            4.0
# ..   ...            ...   ...                       ...            ...
# 731  732    early_years  17.0                   Spotify            2.0
# 732  733   young_adults  18.0                   Spotify            1.0
# 733  734   young_adults  19.0   Other streaming service            6.0
# 734  735   young_adults  19.0                   Spotify            5.0
# 735  736   young_adults  29.0             YouTube Music            2.0
#
#     while_working instrumentalist composer         fav_genre exploratory  ...  \
# ...

# %%
print(df.shape)
# Out:
# (736, 36)

# %% [markdown]
# ### Create database in postgreSQL

# %%
from sqlalchemy_utils import create_database

# user postgres, password, admin
# for example, one wants to create a new db, say, starter
engine = db.create_engine('postgresql://postgres:admin@localhost:5434/musicdb')

# create database
create_database(engine.url)

# release resources associated with engine
engine.dispose()

# %% [markdown]
# ### Create table in PostgreSQL

# %%
# Create connection engine
#user postgres, password admin,database
#engine = db.create_engine('postgresql://auspovuc:bmJdG19Daw9rkEsJ3VnkefRGCBF_oy7F@rain.db.elephantsql.com/auspovuc') 
engine = db.create_engine('postgresql://postgres:admin@localhost:5434/musicdb') 
conn = engine.raw_connection()

# %%
# Create new tables in PostgreSQL

commands = ('''CREATE TABLE IF NOT EXISTS music_survey (
    id INTEGER PRIMARY KEY,
    age INTEGER,
    age_group VARCHAR,
    primary_streaming_service VARCHAR,
    hours_per_day FLOAT,
    while_working VARCHAR,
    instrumentalist VARCHAR,
    composer VARCHAR,
    fav_genre VARCHAR,
    exploratory VARCHAR,
    foreign_languages VARCHAR,
    bpm INTEGER,
    frequency_classical VARCHAR,
    frequency_country VARCHAR,
    frequency_edm VARCHAR,
    frequency_folk VARCHAR,
    frequency_gospel VARCHAR,
    frequency_hip_hop VARCHAR,
    frequency_jazz VARCHAR,
    frequency_k_pop VARCHAR,
    frequency_latin VARCHAR,
    frequency_lofi VARCHAR,
    frequency_metal VARCHAR,
    frequency_pop VARCHAR,
    frequency_r_n_b VARCHAR,
    frequency_rap VARCHAR,
    frequency_rock VARCHAR,
    frequency_video_game_music VARCHAR,
    anxiety VARCHAR,
    depression VARCHAR,
    insomnia VARCHAR,
    ocd VARCHAR,
    music_effects VARCHAR,
    freq1 VARCHAR,
    freq2 VARCHAR,
    freq3 VARCHAR
);''')
            
            
# Initialize connection to PostgreSQL
cur = conn.cursor()

# Create cursor to execute SQL commands

#for command in commands:
cur.execute(commands)

# Commit changes
conn.commit()

# Close communication with server
cur.close()
conn.close()

# %%
# Copy data to table
df.to_sql(name= 'music_survey', con = engine, if_exists= 'replace', index= False)
# Out:
# 736

# %% [markdown]
# ***music_survey table in PostgresSQL***
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Read from PostgreSQL

# %%
engine = db.create_engine('postgresql://postgres:admin@localhost:5434/musicdb') 
conn = engine.raw_connection()

# %%
pd.read_sql('SELECT * FROM music_survey', conn)
# Out:
# C:\Users\Abhirami\AppData\Local\Temp\ipykernel_32660\729649071.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('SELECT * FROM music_survey', conn)
#       id      age_group   age primary_streaming_service  hours_per_day  \
# 0      1   young_adults  18.0                   Spotify            3.0
# 1      2  mature_adults  63.0                   Pandora            1.5
# 2      3   young_adults  18.0                   Spotify            4.0
# 3      4  mature_adults  61.0             YouTube Music            2.5
# 4      5   young_adults  18.0                   Spotify            4.0
# ..   ...            ...   ...                       ...            ...
# 731  732    early_years  17.0                   Spotify            2.0
# 732  733   young_adults  18.0                   Spotify            1.0
# ...
